# %%
import os 
from dotenv import load_dotenv
load_dotenv()

name_db = os.getenv('name_db')
pass_db = os.getenv('pass_db')
host_db =os.getenv('host_db')
postgr  = os.getenv('postgr')
name_user_db = os.getenv('name_user_db')
print(name_db,pass_db,host_db,postgr,name_user_db)
# Out:
# advertdb admin111 localhost:5432 postgresql postgres

# %%
# Out:
# Loading .env environment variables...
# Courtesy Notice: Pipenv found itself running within a virtual environment, so it will automatically use that environment, instead of creating its own for any project. You can set PIPENV_IGNORE_VIRTUALENVS=1 to force pipenv to ignore that environment and create its own instead. You can set PIPENV_VERBOSITY=-1 to suppress this warning.
# bs4==0.0.2
# └── beautifulsoup4 [required: Any, installed: 4.12.3]
#     └── soupsieve [required: >1.2, installed: 2.6]
# email-validator==2.2.0
# ├── dnspython [required: >=2.0.0, installed: 2.7.0]
# └── idna [required: >=2.0.0, installed: 3.10]
# fastapi==0.115.3
# ├── pydantic [required: >=1.7.4,<3.0.0,!=2.1.0,!=2.0.1,!=2.0.0,!=1.8.1,!=1.8, installed: 2.9.2]
# │   ├── annotated-types [required: >=0.6.0, installed: 0.7.0]
# │   ├── pydantic-core [required: ==2.23.4, installed: 2.23.4]
# │   │   └── typing-extensions [required: >=4.6.0,!=4.7.0, installed: 4.12.2]
# ...

# %%
# !pipenv install psycopg2
# Out:
# Loading .env environment variables...
# Courtesy Notice: Pipenv found itself running within a virtual environment, so it will automatically use that environment, instead of creating its own for any project. You can set PIPENV_IGNORE_VIRTUALENVS=1 to force pipenv to ignore that environment and create its own instead. You can set PIPENV_VERBOSITY=-1 to suppress this warning.
# Installing psycopg2...
# Resolving psycopg2...
# ✔ Installation Succeeded
# ⠋ Installing psycopg2...
# Installing dependencies from Pipfile.lock (5e5126)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
